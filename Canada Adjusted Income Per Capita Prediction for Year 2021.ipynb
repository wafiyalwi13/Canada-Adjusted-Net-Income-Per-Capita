# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Canada - Adjusted Income Per Capita.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    51 non-null     int64
#  1   Income  51 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 948.0 bytes

# %%
data.dtypes
# Out:
# Year        int64
# Income    float64
# dtype: object

# %%
data.head()
# Out:
#    Year       Income
# 0  1970  3429.756623
# 1  1971  3774.182973
# 2  1972  4278.766586
# 3  1973  4861.052386
# 4  1974  5705.506544

# %%
sns.regplot(x='Year', y='Income', data=data)
# Out:
# <Axes: xlabel='Year', ylabel='Income'>

# %%
#predict income percapita for year 2021
#regression 
#1. create instance

# fit method - 1st argument is independant variables (year column) called as feature 
#            - 2nd argument is dependant variables (income column) target variables

# %%
lri = LinearRegression()

# %%
lri.fit(data[['Year']].values, data.Income)
# Out:
# LinearRegression()

# %%
lri.predict([[2021]])
# Out:
# array([41423.87253806])
